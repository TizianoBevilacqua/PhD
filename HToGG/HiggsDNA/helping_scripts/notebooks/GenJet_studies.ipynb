# %% [markdown]
# # Basic Example

# %%
import awkward as ak
import numpy as np
import uproot
import hist
import json
from importlib import resources
import matplotlib.pyplot as plt
import mplhep as hep
from cycler import cycler
from datetime import date

# %%
acab_palette = ["#3f90da", "#ffa90e", "#bd1f01", "#94a4a2", "#832db6", "#a96b59", "#e76300", "#717581", "#92dadd"]
#hep.styles.cms.CMS["axes.prop_cycle"] # = cycler("color", acab_palette[::-1])
hep.style.use("CMS")

# %%
# Get the current date
current_date = date.today()
# Format the date
formatted_date = current_date.strftime("%y%m%d")

# %%
MULTICLASS = False

processes = [
    "cH_4FS_FXFX_M125_2017",
]
branches = ["Photon", "Jet", "Electron", "GenJet", "GenPart", "GenWeight"]

# %%
# %%!
# ls -l /pnfs/psi.ch/cms/trivcat/store/user/bevila_t/test2/phys/xpluscharm/Out_nAODs/Private_MC_production/4FS_FXFX_HToGG_2017_allgenpart/
# Out:
# ['total 8400250',
#  '-rw-r--r--   1 bevila_t psi-pixel      5407 Apr 20  2023 genXSecAn.txt',
#  'drwxr-xr-x 190 bevila_t psi-pixel       512 Apr 20  2023 logs',
#  'drwxr-xr-x   2 bevila_t psi-pixel       512 Sep 27  2022 merged',
#  '-rw-r--r--   1 bevila_t psi-pixel  34708697 Sep 27  2022 nAOD_0001.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  67659297 Sep 27  2022 nAOD_0002.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  23243259 Sep 27  2022 nAOD_0003.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  69758114 Sep 27  2022 nAOD_0004.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 107598278 Sep 27  2022 nAOD_0005.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 143600976 Sep 27  2022 nAOD_0006.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 145840317 Sep 27  2022 nAOD_0007.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  52847302 Sep 27  2022 nAOD_0008.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  61745103 Sep 27  2022 nAOD_0009.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  28398371 Sep 27  2022 nAOD_0010.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  81473523 Sep 27  2022 nAOD_0011.root',
#  '-rw-r--r--   1 bevila_t psi-pixel   9793804 Sep 27  2022 nAOD_0012.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  75861776 Sep 27  2022 nAOD_0013.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  39892505 Sep 27  2022 nAOD_0014.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  14812444 Sep 27  2022 nAOD_0015.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 142647339 Sep 27  2022 nAOD_0016.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 197947058 Sep 27  2022 nAOD_0017.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  48204487 Sep 27  2022 nAOD_0018.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  54241653 Sep 27  2022 nAOD_0019.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  31254794 Sep 27  2022 nAOD_0020.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  74459757 Sep 27  2022 nAOD_0021.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 154398568 Sep 27  2022 nAOD_0022.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 163276636 Sep 27  2022 nAOD_0023.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 164659556 Sep 27  2022 nAOD_0024.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 102942082 Sep 27  2022 nAOD_0025.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  87905181 Sep 27  2022 nAOD_0026.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  79400307 Sep 27  2022 nAOD_0027.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  99691389 Sep 27  2022 nAOD_0028.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  66163740 Sep 27  2022 nAOD_0029.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  36612224 Sep 27  2022 nAOD_0030.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  34756032 Sep 27  2022 nAOD_0031.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  19932372 Sep 27  2022 nAOD_0032.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  38381596 Sep 27  2022 nAOD_0033.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  39432730 Sep 27  2022 nAOD_0034.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  67782637 Sep 27  2022 nAOD_0035.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  28194361 Sep 27  2022 nAOD_0036.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  39415162 Sep 27  2022 nAOD_0037.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  66006638 Sep 27  2022 nAOD_0038.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  36720548 Sep 27  2022 nAOD_0039.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  86471959 Sep 27  2022 nAOD_0040.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 147484392 Sep 27  2022 nAOD_0041.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 101009239 Sep 27  2022 nAOD_0042.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  34298251 Sep 27  2022 nAOD_0043.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 159182882 Sep 27  2022 nAOD_0044.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  84066940 Sep 27  2022 nAOD_0045.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 162130247 Sep 27  2022 nAOD_0046.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  59512091 Sep 27  2022 nAOD_0047.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  69699026 Sep 27  2022 nAOD_0048.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  99594671 Sep 29  2022 nAOD_0049.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  46136574 Sep 27  2022 nAOD_0050.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  86200406 Sep 27  2022 nAOD_0051.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  36569520 Sep 27  2022 nAOD_0052.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  14784464 Sep 27  2022 nAOD_0053.root',
#  '-rw-r--r--   1 bevila_t psi-pixel   8261126 Sep 27  2022 nAOD_0054.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 112305412 Sep 27  2022 nAOD_0055.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  48191283 Sep 27  2022 nAOD_0056.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  71387851 Sep 27  2022 nAOD_0057.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  39600103 Sep 27  2022 nAOD_0058.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  21580805 Sep 27  2022 nAOD_0059.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 115565270 Sep 27  2022 nAOD_0060.root',
#  '-rw-r--r--   1 bevila_t psi-pixel   8066223 Sep 27  2022 nAOD_0061.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  28151081 Sep 27  2022 nAOD_0062.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  24720863 Sep 27  2022 nAOD_0063.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  11470250 Sep 27  2022 nAOD_0064.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  99061385 Sep 27  2022 nAOD_0065.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 145391333 Sep 27  2022 nAOD_0066.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  98069574 Sep 27  2022 nAOD_0067.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  86158948 Sep 27  2022 nAOD_0068.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 163914208 Sep 29  2022 nAOD_0069.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 130629579 Sep 27  2022 nAOD_0070.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  96211266 Sep 27  2022 nAOD_0071.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 156968243 Sep 27  2022 nAOD_0072.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 175148348 Sep 27  2022 nAOD_0073.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 150888413 Sep 27  2022 nAOD_0074.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 208310489 Sep 27  2022 nAOD_0075.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 192288628 Sep 27  2022 nAOD_0076.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 149479006 Sep 27  2022 nAOD_0077.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 218880779 Sep 27  2022 nAOD_0078.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 198538454 Sep 27  2022 nAOD_0079.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 215585035 Sep 27  2022 nAOD_0080.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 216400060 Sep 27  2022 nAOD_0081.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 242262495 Sep 27  2022 nAOD_0082.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 221294576 Sep 27  2022 nAOD_0083.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 163104353 Sep 27  2022 nAOD_0084.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 103455179 Sep 27  2022 nAOD_0085.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  11611218 Sep 27  2022 nAOD_0086.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  25019372 Sep 27  2022 nAOD_0087.root',
#  '-rw-r--r--   1 bevila_t psi-pixel   6588694 Sep 27  2022 nAOD_0088.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 167058447 Sep 27  2022 nAOD_0089.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 109774741 Sep 27  2022 nAOD_0090.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  85881419 Sep 27  2022 nAOD_0091.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 121239014 Sep 27  2022 nAOD_0092.root',
#  '-rw-r--r--   1 bevila_t psi-pixel 104725958 Sep 27  2022 nAOD_0093.root',
#  '-rw-r--r--   1 bevila_t psi-pixel  29786380 Sep 27  2022 nAOD_0094.root']

# %%
fileset = {}

for i, proc in enumerate(processes):
    input_dir = f"/pnfs/psi.ch/cms/trivcat/store/user/bevila_t/test2/phys/xpluscharm/Out_nAODs/Private_MC_production/4FS_FXFX_HToGG_2017_allgenpart/" # this is CvsL ordered with multiclass bdt
    fileset[proc] = uproot.concatenate(f"{input_dir}/*000*.root:Events", library="ak", branches=branches)

# %%
lumi = {
    "2016" : 35.9,
    "2017" : 41.5,
    "2018" : 59.2
}

norm_1fb = {
    "ggh": 48.58 * 0.00227 * 1000,
    "tth": 0.5071 * 0.00227 * 1000,
    "vbf": 3.782 * 0.00227 * 1000,
    "vh": 2.2555 * 0.00227 * 1000,
    "bh": 0.6654 * 0.00227 * 1000,
    "ch": 0.09013 * 0.00227 * 1000,
}

# %%
for f in fileset[[*fileset][0]].fields:
    #if "L1" not in f and "HLT" not in f:
    if "GenJet" in f:
        print(f)
# Out:
# nGenJetAK8
# GenJetAK8_eta
# GenJetAK8_mass
# GenJetAK8_phi
# GenJetAK8_pt
# nGenJet
# GenJet_eta
# GenJet_mass
# GenJet_phi
# GenJet_pt
# nSubGenJetAK8
# SubGenJetAK8_eta
# SubGenJetAK8_mass
# SubGenJetAK8_phi
# SubGenJetAK8_pt
# GenJetAK8_partonFlavour
# GenJetAK8_hadronFlavour
# GenJet_partonFlavour
# GenJet_hadronFlavour

# %%
mask_jet[0]
# Out:
# <Array [True, True, False] type='3 * bool'>

# %%
mask_jet = (fileset[[*fileset][0]].Jet_pt > 20) & (abs(fileset[[*fileset][0]].Jet_eta) < 2.5)
mask_genjet = (fileset[[*fileset][0]].GenJet_pt > 10) & (abs(fileset[[*fileset][0]].GenJet_eta) < 2.5)

for i in range(100):
    if (len(fileset[[*fileset][0]].Jet_pt[mask_jet][i]))  or (len(fileset[[*fileset][0]].GenJet_pt[mask_genjet][i])):
        print(i)
        print("    Jet   :", fileset[[*fileset][0]].Jet_hadronFlavour[mask_jet][i], fileset[[*fileset][0]].Jet_eta[mask_jet][i],  fileset[[*fileset][0]].Jet_pt[mask_jet][i], fileset[[*fileset][0]].Jet_particleNetAK4_CvsL[mask_jet][i])
        print("    GenJet:", fileset[[*fileset][0]].GenJet_hadronFlavour[mask_genjet][i],  fileset[[*fileset][0]].GenJet_eta[mask_genjet][i], fileset[[*fileset][0]].GenJet_pt[mask_genjet][i],)
# Out:
# 0
#     Jet   : [0, 0] [0.619, 2.11] [61.2, 56.1] [0.0387, 0.0318]
#     GenJet: [0, 0] [0.58, 2.09] [56.3, 47.8]
# 2
#     Jet   : [0, 0] [1.29, 2.16] [69.1, 66.2] [0.013, 0.018]
#     GenJet: [0, 0] [1.3, 2.17] [59, 55.2]
# 3
#     Jet   : [0, 4, 0, 0] [0.453, 0.969, 0.0972, 2.22] [209, 170, 70.7, 31.6] [0.0142, 0.0771, 0.00863, 0.103]
#     GenJet: [4, 0, 0, 0] [0.967, 0.449, 0.105, 2.21] [185, 165, 61.4, 31.2]
# 4
#     Jet   : [0, 4, 0] [2.04, 1.85, -1.37] [38, 28.5, 21.1] [0.0405, 0.147, 0.0331]
#     GenJet: [4, 0, 0] [1.85, 2.07, -1.38] [34.5, 31.7, 18.7]
# 6
#     Jet   : [4, 0, 0, 0, 0] [-0.112, -2.1, 2.2, 2.16, 1.04] [70.2, 49.3, 49.3, 28.3, 22.7] [0.0906, 0.0415, 0.0534, 0.0701, 0.046]
#     GenJet: [4, 0, 0, 0, 0, 0, 0] [-0.147, 2.18, 2.15, -2.1, 1.02, 2.36, -0.201] [77.8, 75.1, 46.3, 38.8, 23.7, 12.3, 11.3]
# 7
#     Jet   : [0, 0, 4] [0.266, 1.73, -0.917] [74.9, 48.6, 43.4] [0.0189, 0.0342, 0.0637]
#     GenJet: [0, 4, 0] [0.269, -0.938, 1.73] [72.6, 39.9, 39.3]
# 8
#     Jet   : [0, 0, 0] [0.968, 1.95, -0.217] [68.2, 59.7, 23.1] [0.0108, 0.0173, 0.0454]
#     GenJet: [0, 0] [0.97, 1.95] [61.5, 50.4]
# 9
#     Jet   : [0, 0] [-1.08, 1.09] [53.2, 33] [0.0241, 0.0276]
#     GenJet: [0, 0] [-1.08, 1.08] [46.6, 31.5]
# 10
#     Jet   : [0, 0] [1.21, 2.4] [75.2, 67.6] [0.0075, 0.0481]
#     GenJet: [0, 0, 0] [1.21, 2.4, -1.14] [68.8, 52.3, 13.6]
# 11
#     Jet   : [0, 0, 4] [1.03, 0.722, -0.845] [83.1, 66.4, 47.8] [0.0177, 0.017, 0.413]
#     GenJet: [0, 0, 4] [1.02, 0.747, -0.816] [73.9, 56.4, 49.7]
# 12
#     Jet   : [0, 0, 4] [0.409, 1.62, -0.158] [96.8, 80.1, 28.2] [0.0356, 0.011, 0.575]
#     GenJet: [0, 0, 4] [0.386, 1.61, -0.333] [95.2, 80.5, 26.7]
# 13
#     Jet   : [0, 0, 0] [-0.971, -0.762, -1.15] [90.3, 73.8, 64.4] [0.0073, 0.05, 0.0183]
#     GenJet: [0, 0, 0, 0, 4] [-0.972, -0.767, -1.15, -2.48, -0.0678] [84.3, 69.5, 65, 13.4, 11.1]
# 14
#     Jet   : [0, 0] [1.97, 1.74] [92.1, 72.4] [0.0657, 0.0217]
#     GenJet: [0, 0] [1.98, 1.75] [73.3, 56]
# 15
#     Jet   : [5, 4, 0, 0] [-1.21, -1.28, -0.179, 2.11] [105, 50.6, 44.4, 20] [0.0163, 0.117, 0.0379, 0.0925]
#     GenJet: [5, 4, 0, 4] [-1.23, -1.27, -0.181, 1.02] [93.1, 45.1, 40.7, 11.9]
# 16
#     Jet   : [0, 0, 0] [-0.842, 0.83, -2.02] [66.2, 43, 20.6] [0.0343, 0.02, 0.0486]
#     GenJet: [0, 0, 0, 0] [-0.869, 0.818, 1.23, -2.02] [48.8, 43.3, 11.3, 10.2]
# 17
#     Jet   : [0] [-2.42] [97] [0.0565]
#     GenJet: [0] [-2.42] [63.9]
# 18
#     Jet   : [0, 0] [1.81, 2.25] [62, 25.2] [0.0093, 0.0554]
#     GenJet: [0, 0] [1.81, 2.31] [54.3, 33]
# 19
#     Jet   : [0] [-2.11] [58.9] [0.0239]
#     GenJet: [0] [-2.06] [48.4]
# 20
#     Jet   : [0, 0] [-1.19, -1.67] [82.9, 65.1] [0.00982, 0.0307]
#     GenJet: [0, 0, 4] [-1.2, -1.64, -2.18] [74.2, 53.4, 18.9]
# 21
#     Jet   : [0, 0, 0, 0] [0.931, 1.35, 0.374, -0.651] [78.2, 61, 34.8, 25.1] [0.014, 0.0161, 0.0366, 0.0576]
#     GenJet: [0, 0, 0] [0.893, 1.3, -1.58] [70.9, 53.3, 16.1]
# 22
#     Jet   : [0] [1.82] [68.2] [0.0217]
#     GenJet: [0, 0] [2.49, 1.81] [61.2, 57]
# 23
#     Jet   : [4, 0, 4] [0.287, 1.64, 0.0531] [77.2, 54.5, 50.1] [0.0188, 0.0298, 0.999]
#     GenJet: [4, 4, 0, 0, 0] [0.295, 0.04, 1.66, -0.843, -1.24] [71.5, 51, 42.4, 17.2, 13.1]
# 24
#     Jet   : [0, 0] [-1.58, -0.955] [112, 71.1] [0.0883, 0.0194]
#     GenJet: [0, 0, 0, 0] [-1.56, -0.99, -2.23, -0.368] [95.8, 46.2, 17.8, 13]
# 25
#     Jet   : [0] [-2.1] [56.8] [0.0217]
#     GenJet: [0, 0] [-2.1, 2] [48.8, 14.4]
# 26
#     Jet   : [0, 0] [-2.5, -0.522] [62.8, 41.7] [0.0708, 0.0236]
#     GenJet: [0] [-0.556] [40.3]
# 27
#     Jet   : [0, 0] [-1.94, -0.724] [63.4, 58.7] [0.0204, 0.0149]
#     GenJet: [0, 0] [-0.736, -1.94] [57.8, 49.4]
# 28
#     Jet   : [0] [-0.31] [45.6] [0.0501]
#     GenJet: [0] [-0.381] [32.4]
# 29
#     Jet   : [0, 0, 0, 0] [-0.67, -0.406, 0.102, -0.754] [75.6, 62.3, 33.2, 27.8] [0.0319, 0.0154, 0.0292, 0.0741]
#     GenJet: [0, 0, 0, 0, 4, 0, 4, 0] [-0.672, -0.404, 0.11, -0.682, 1.12, 0.494, -2, 0.545] [71, 58.6, 34.7, 24.2, 21.1, 13.3, 11.7, 10.5]
# 30
#     Jet   : [0, 0, 0] [0.544, 1.39, 1.88] [72.3, 60.3, 20.1] [0.0281, 0.0193, 0.102]
#     GenJet: [0, 0, 0] [0.547, 1.39, 1.87] [61.2, 54.2, 10.4]
# 31
#     Jet   : [0, 0, 0] [-0.187, 1.64, 1.38] [77.1, 38.6, 22.1] [0.0188, 0.0378, 0.0876]
#     GenJet: [0, 0, 4, 0] [-0.191, 1.67, 0.277, 0.409] [70.8, 29.1, 20.3, 20]
# 32
#     Jet   : [0, 0, 0] [-2.24, -2.17, -2.09] [83.8, 69.3, 33.3] [0.0384, 0.0185, 0.107]
#     GenJet: [0, 0] [-2.25, -2.17] [64.4, 61.7]
# 33
#     Jet   : [0, 0] [-1.63, -1.04] [107, 54.5] [0.0342, 0.0159]
#     GenJet: [0, 0, 0, 0] [-1.63, -1.05, 1.74, 2.27] [86.1, 47, 19.7, 13.4]
# 34
#     Jet   : [0, 0, 4, 0] [-0.565, -2.31, 0.984, -2.04] [59.7, 58.3, 29.6, 23] [0.0251, 0.0226, 0.842, 0.111]
#     GenJet: [0, 0, 4] [-0.55, -2.3, 0.999] [53.2, 40.1, 24.7]
# 35
#     Jet   : [0, 0] [2.19, -0.966] [88, 29] [0.02, 0.0286]
#     GenJet: [0] [2.2] [66]
# 36
#     Jet   : [0, 0] [2.42, -0.711] [72, 29.5] [0.127, 0.0598]
#     GenJet: [0] [2.44] [43.3]
# 37
#     Jet   : [0, 0, 0] [-1.2, -1.68, -1.58] [70.9, 68.8, 22] [0.0266, 0.0352, 0.085]
#     GenJet: [0, 0] [-1.66, -1.19] [62, 61.1]
# 38
#     Jet   : [0, 0, 0] [-1.85, -0.695, -2.05] [73.8, 71.8, 22.4] [0.0152, 0.0735, 0.0809]
#     GenJet: [0, 0, 0] [-1.84, -0.731, -2.1] [60.6, 51.9, 13.9]
# 39
#     Jet   : [0, 0] [1.29, 0.0151] [72.2, 51.8] [0.0529, 0.0312]
#     GenJet: [0, 0, 0] [0.0348, 1.33, 0.933] [63.6, 51.8, 14.7]
# 40
#     Jet   : [0, 0, 0] [1.85, 0.622, -0.388] [80.6, 46.3, 21.6] [0.0217, 0.0233, 0.0674]
#     GenJet: [0, 0] [1.84, 0.617] [63.6, 46.2]
# 41
#     Jet   : [0, 0] [-1.57, -0.269] [77.1, 42.7] [0.0161, 0.0221]
#     GenJet: [0, 0, 4, 0] [-1.57, -0.263, -2.1, -1.22] [69.8, 38.7, 16.1, 11.3]
# 42
#     Jet   : [0, 0, 0] [-1.05, 0.975, -0.717] [52.5, 45.3, 25.1] [0.0287, 0.0273, 0.0413]
#     GenJet: [0, 0, 0, 0] [-1.05, 0.954, 1.15, -1.74] [45.6, 40.9, 21.9, 13.2]
# 43
#     Jet   : [0, 4, 4, 0] [0.898, -0.152, -1.33, 0.14] [79.6, 45.5, 32.1, 31.8] [0.0727, 0.0528, 0.414, 0.0912]
#     GenJet: [0, 4, 4] [0.885, -0.146, -1.3] [75.4, 42.4, 36.5]
# 44
#     Jet   : [0, 0] [1.24, 0.649] [69.8, 68.6] [0.0173, 0.019]
#     GenJet: [0, 0, 4] [0.635, 1.2, -2.45] [70.4, 55.5, 14.9]
# 45
#     Jet   : [0, 4] [0.437, -1.4] [74.9, 65.2] [0.0141, 0.157]
#     GenJet: [0, 4, 0] [0.433, -1.41, 1.81] [70.3, 68.9, 46]
# 47
#     Jet   : [0, 0] [0.366, 2.3] [52.3, 44.2] [0.00809, 0.0235]
#     GenJet: [0, 0, 4] [0.372, 2.31, 0.556] [52.9, 37.3, 11.1]
# 48
#     Jet   : [0, 0] [1.91, 2.37] [81.4, 74.8] [0.0158, 0.0163]
#     GenJet: [0, 0] [1.91, 2.34] [66.6, 61.6]
# 49
#     Jet   : [0, 4, 0, 4] [-1.57, 1.45, 0.899, -2.36] [72.5, 38.8, 34.4, 28.2] [0.00595, 0.202, 0.0402, 0.461]
#     GenJet: [0, 4, 0, 4, 0] [-1.56, 1.42, 0.871, -2.42, -2.38] [55.7, 40.4, 25.1, 20.6, 10.2]
# 50
#     Jet   : [0, 0, 0, 4] [0.16, -1.85, -1.52, 1.24] [52.1, 40, 34.7, 23.5] [0.0118, 0.0213, 0.0627, 0.0864]
#     GenJet: [0, 0, 0, 4] [0.158, -1.85, -1.52, 1.27] [48.8, 34.4, 29.3, 17.6]
# 51
#     Jet   : [0, 0, 4, 0, 0] [1.08, -0.71, 0.0252, -1.44, 2.43] [53.3, 45.8, 23.8, 21.6, 21.2] [0.0161, 0.0164, 0.57, 0.113, 0.0674]
#     GenJet: [0, 0, 4, 0] [1.07, -0.707, -0.0515, -1.46] [45.4, 44.5, 22.1, 12.8]
# 52
#     Jet   : [0, 0] [-0.247, -0.0907] [92.8, 66.1] [0.107, 0.0178]
#     GenJet: [0, 0] [-0.282, -0.0833] [69.6, 56.3]
# 53
#     Jet   : [0, 0] [2.1, 0.708] [71.1, 55.7] [0.0412, 0.023]
#     GenJet: [0, 0] [0.729, 2.12] [52.6, 49.4]
# 54
#     Jet   : [0, 0] [1.82, -0.623] [45.7, 39.8] [0.0226, 0.0186]
#     GenJet: [0, 0, 4] [-0.64, 1.8, -1.78] [36.8, 36.3, 15.9]
# 55
#     Jet   : [] [] [] []
#     GenJet: [0] [-2.14] [10.1]
# 56
#     Jet   : [0, 0, 0, 0] [-2.4, -0.811, -2.13, 1.22] [46.4, 31.6, 27.8, 20.7] [0.0681, 0.103, 0.108, 0.0688]
#     GenJet: [0, 0, 0, 0] [-0.763, -2.36, 1.22, -2.07] [38.3, 32.6, 16, 10.6]
# 57
#     Jet   : [0, 0, 0] [0.999, -1.09, -1.78] [53.3, 37.1, 23.8] [0.01, 0.0179, 0.0684]
#     GenJet: [0, 0, 0, 4] [0.994, -1.1, -1.89, -2.39] [50, 34.7, 15.4, 11.9]
# 58
#     Jet   : [0, 0, 0] [-1.1, 1.91, -0.517] [61.9, 29.3, 20.3] [0.0507, 0.0414, 0.0366]
#     GenJet: [0, 0] [-1.01, 1.95] [41.8, 22.6]
# 59
#     Jet   : [0, 0] [0.59, 0.549] [77.2, 56.9] [0.0158, 0.0133]
#     GenJet: [0, 0] [0.592, 0.553] [72.6, 55]
# 60
#     Jet   : [0, 0, 0] [-0.186, 1.94, -1.08] [50.2, 44.8, 38.3] [0.0196, 0.00994, 0.0653]
#     GenJet: [0, 0, 0, 0, 0] [-0.205, 1.96, -1.09, -1.57, 2.12] [45.2, 37.5, 34.6, 20.2, 10.8]
# 61
#     Jet   : [0, 0] [-0.304, -0.472] [77.2, 65.1] [0.0369, 0.0183]
#     GenJet: [0, 0] [-0.34, -0.516] [69.7, 57]
# 62
#     Jet   : [0, 0] [-2.38, -1.11] [51.8, 50.7] [0.0521, 0.0177]
#     GenJet: [0, 4] [-1.17, -1.11] [45.4, 24.6]
# 63
#     Jet   : [4] [0.579] [32.6] [0.533]
#     GenJet: [4, 0, 0] [0.588, -1.7, 1.84] [34.6, 25.5, 20.5]
# 64
#     Jet   : [0, 4, 0] [-2.32, -0.459, 0.303] [72.2, 42.4, 41.6] [0.0324, 0.101, 0.0146]
#     GenJet: [0, 4, 0, 0] [-2.3, -0.472, 0.311, 2.36] [72.4, 50.6, 42.4, 14.6]
# 65
#     Jet   : [0, 4] [0.287, 0.984] [35.1, 26.6] [0.029, 0.142]
#     GenJet: [0, 4, 0] [0.272, 0.876, 0.855] [28.3, 26.9, 11.7]
# 66
#     Jet   : [0, 0, 0] [-1.15, -1.27, -2.27] [72.6, 72.2, 22.4] [0.0311, 0.0232, 0.0657]
#     GenJet: [0, 0] [-1.12, -1.27] [65.5, 61.9]
# 67
#     Jet   : [0, 0] [-0.652, -2.43] [27.9, 26.5] [0.0685, 0.0962]
#     GenJet: [0, 0, 4] [1.83, -2.37, 0.488] [28.3, 18.7, 17.1]
# 68
#     Jet   : [0, 0] [-1.77, 1.65] [30.4, 24.9] [0.021, 0.0361]
#     GenJet: [0, 0] [-1.78, 1.67] [26.2, 19.7]
# 69
#     Jet   : [0, 0] [-0.0591, -2.26] [33.2, 24.8] [0.0281, 0.0922]
#     GenJet: [0, 0, 0] [0.0131, 0.956, 0.601] [26.5, 18.3, 12.9]
# 70
#     Jet   : [4, 0] [2.02, 0.663] [95.9, 79.9] [0.00546, 0.0237]
#     GenJet: [4, 0, 4] [2.02, 0.681, 1.4] [82, 71.4, 14.9]
# 71
#     Jet   : [0, 0, 4] [1.21, 2.49, -0.506] [87.4, 55.4, 31.6] [0.0278, 0.0443, 0.639]
#     GenJet: [0, 0, 4, 0] [1.22, 2.44, -0.49, -2.05] [75.7, 39, 31.9, 10.6]
# 72
#     Jet   : [0, 0, 0] [1.33, 0.716, -0.709] [78.4, 59.8, 20.5] [0.0115, 0.024, 0.0757]
#     GenJet: [0, 0, 0, 0, 0] [1.33, 0.713, 0.542, -0.657, 1.76] [68.5, 54.7, 14.3, 11.4, 10.5]
# 73
#     Jet   : [0, 0] [-1.19, -0.737] [73.5, 73.2] [0.0173, 0.0179]
#     GenJet: [0, 0, 0] [-1.2, -0.763, 1.66] [64.1, 61.7, 13.5]
# 74
#     Jet   : [0, 0, 4, 4] [0.824, 1.13, 2.15, -1.95] [99.5, 60.8, 29.2, 21.1] [0.0158, 0.013, 0.211, 0.104]
#     GenJet: [0, 0, 4, 4] [0.826, 1.1, 2.16, -1.94] [91.3, 47.6, 41.2, 25.1]
# 75
#     Jet   : [0] [-0.275] [47.8] [0.0316]
#     GenJet: [0] [-0.299] [27.9]
# 76
#     Jet   : [0, 0] [2.4, 0.885] [96.4, 40.2] [0.0344, 0.0371]
#     GenJet: [0, 0] [2.39, 0.778] [75.7, 30.6]
# 77
#     Jet   : [0, 0] [1.08, 1.45] [87.6, 62.8] [0.014, 0.0147]
#     GenJet: [0, 0, 4] [1.08, 1.45, -1.88] [75.5, 52.4, 16.2]
# 78
#     Jet   : [0, 0, 0] [-1.79, -0.561, 1.52] [79.1, 43.2, 26.2] [0.00961, 0.0224, 0.067]
#     GenJet: [0, 0, 0] [-1.78, -0.56, -0.742] [70.7, 40.8, 27.8]
# 79
#     Jet   : [0, 0, 4] [0.577, -0.427, -1.65] [65.1, 57, 21.9] [0.00988, 0.00482, 0.797]
#     GenJet: [0, 0, 4] [0.578, -0.419, -1.66] [60.3, 51.3, 25.1]
# 80
#     Jet   : [0, 4] [0.634, 0.0462] [67.2, 60.6] [0.00976, 0.0417]
#     GenJet: [0, 4, 0] [0.634, 0.0442, -1.82] [66.8, 63.1, 10.2]
# 81
#     Jet   : [0, 0] [1.95, 1.85] [83.4, 70.8] [0.0126, 0.0365]
#     GenJet: [0, 0, 4] [1.94, 1.84, -0.437] [67.1, 58.2, 13.3]
# 82
#     Jet   : [0, 0] [-1.27, 1.58] [53, 20.3] [0.023, 0.0466]
#     GenJet: [0, 4] [-1.29, 2.08] [44.1, 13.1]
# 83
#     Jet   : [] [] [] []
#     GenJet: [0] [-2.44] [15.6]
# 84
#     Jet   : [0, 0] [0.303, 0.211] [82.1, 60.8] [0.0114, 0.0222]
#     GenJet: [0, 0, 4] [0.263, 0.16, -1.05] [76.4, 55.9, 18.3]
# 85
#     Jet   : [0, 0] [-2.16, -0.827] [69.4, 55.2] [0.0189, 0.0159]
#     GenJet: [0, 0] [-2.17, -0.857] [54.7, 49.6]
# 86
#     Jet   : [0, 0, 0] [1.3, -0.454, -1.81] [89.6, 29, 27] [0.0283, 0.0256, 0.149]
#     GenJet: [0, 0, 0, 4, 0] [1.3, -0.475, 0.783, 0.217, 1.83] [74.4, 28.1, 18.2, 13.6, 13.5]
# 87
#     Jet   : [0, 0, 0, 0] [1.03, 1.5, 2.26, 0.695] [80.7, 68.2, 32.5, 25.6] [0.0197, 0.0281, 0.0681, 0.0726]
#     GenJet: [0, 0, 0] [0.98, 1.46, 2.27] [76, 51.7, 20.5]
# 88
#     Jet   : [0, 0] [1.16, 2.29] [69.9, 61.5] [0.0185, 0.0184]
#     GenJet: [0, 0] [1.18, 2.28] [63.4, 49.2]
# 89
#     Jet   : [0] [-1.1] [29.9] [0.0332]
#     GenJet: [0] [-1.16] [26.3]
# 90
#     Jet   : [0, 0] [0.199, 1.22] [65.2, 63.8] [0.0206, 0.011]
#     GenJet: [0, 0] [0.2, 1.22] [58.8, 56.7]
# 91
#     Jet   : [0, 0, 4] [-0.00969, 0.943, 0.883] [65.2, 45.1, 39.2] [0.0443, 0.0349, 0.114]
#     GenJet: [0, 0, 4] [0.00681, 0.921, 0.914] [67, 54, 31.3]
# 92
#     Jet   : [0, 0, 0, 0] [-1.34, 2.28, 1.46, 2.08] [71.9, 32.6, 24.7, 22.2] [0.0223, 0.0925, 0.0791, 0.0535]
#     GenJet: [0, 4] [-1.34, -0.606] [54.4, 13.7]
# 93
#     Jet   : [0, 0] [0.655, 0.664] [70.5, 68.3] [0.0296, 0.0187]
#     GenJet: [0, 0, 4, 0] [0.666, 0.672, -0.59, 1.77] [67.2, 64.5, 15.3, 11.1]
# 94
#     Jet   : [0, 0, 0] [0.427, 1.83, -0.57] [63.8, 50.9, 22.8] [0.0163, 0.0234, 0.0695]
#     GenJet: [0, 0, 0] [0.476, 1.86, 0.259] [57.3, 44.2, 10.9]
# 95
#     Jet   : [0, 0, 0, 0, 0] [0.0905, 1.79, 1.15, -1.99, 0.864] [71.2, 42.1, 25.1, 21.6, 21.1] [0.063, 0.0759, 0.808, 0.101, 0.102]
#     GenJet: [0, 0] [0.0737, 1.77] [59.3, 44.5]
# 96
#     Jet   : [0] [1.13] [42.5] [0.025]
#     GenJet: [0] [1.1] [31.3]
# 97
#     Jet   : [4] [-0.194] [31.1] [0.657]
#     GenJet: [4, 0] [-0.182, -2.5] [34.8, 34.8]
# 98
#     Jet   : [0, 0] [-0.948, -1.18] [69.8, 68.6] [0.00404, 0.0134]
#     GenJet: [0, 0] [-0.952, -1.18] [64.3, 62.7]
# 99
#     Jet   : [0, 0] [-1.75, -0.689] [80.7, 32.4] [0.0532, 0.167]
#     GenJet: [0, 0] [-1.76, -0.721] [71.4, 59.3]
